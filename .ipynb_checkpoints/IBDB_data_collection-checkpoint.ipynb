# %% [markdown]
# # IBDB Webscraping
# This file webscrapes publically available data from the Broadway League's IBDB (Internet Broadway Database) for the purposes of analyzing the importance of Tony Awards outcomes for Broadway Productions.
#
# This file borrows code and takes general inspiration from the following [Colaboratory Jupyter Notebook](https://colab.research.google.com/drive/1IVwOhBMYay14NkO7kGkrPu0Ij9dSDdEP) by Yaakov Bressler

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import re
import string
import time
import datetime
import pandas as pd
import numpy as np
import urllib
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Create a function that grabs links from a page, using a tag to identify value of link

# %%
def getLinks_tagged_fast(url, tag):
    r = requests.get(url)
    html_doc = r.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    links = []
    # set the opening of each link to be...
    tag = tag
    for link in soup.findAll('a', attrs={'href': re.compile(tag)}):
        links.append(link.get('href'))
    return links

# %% [markdown]
# https://www.broadwayworld.com/browseshows.cfm?showtype=BR
#
# The above link is your starting point. It will allow us to get the name of every Broadway production that opened between 1979 and now.

# %%
def get_show_links_year(year_url):

    url = year_url
    tag_year = 'browseshows.cfm?'
    #calling previous function to get the link I want
    years = getLinks_tagged_fast(url, tag_year)[1:]
    page_base = 'https://www.broadwayworld.com/'
    years_loop =[]
    for year in years:
        #focusing on 1979 or later
        if year[-4:].isdigit() and int(year[-4:]) >= 1979:
            years_loop.append(page_base+year)
    
    # Now you have all the years
    tag_show = 'https://www.broadwayworld.com/shows/backstage.php?'
    show_links_nested = []
    for year in years_loop:
        show_links_nested.append(getLinks_tagged_fast(year,tag_show))
    show_links = sum(show_links_nested, [])
    
    return show_links
    
#running function to get my list of links to the productions I want
year_url = 'https://www.broadwayworld.com/browseshows.cfm?showtype=BR'
show_links = get_show_links_year(year_url)

# %%
#don't need every show ever, just 1979 onwards
#from here, scrape name of show, so you can search for it on ibdb.com
print(show_links)
#the number of productions between 1979 and now fits the estimate I made in another assignment (roughly 1800)
len(show_links)
# Out:
# ['https://www.broadwayworld.com/shows/backstage.php?showid=334234', 'https://www.broadwayworld.com/shows/backstage.php?showid=334473', 'https://www.broadwayworld.com/shows/backstage.php?showid=334678', 'https://www.broadwayworld.com/shows/backstage.php?showid=334174', 'https://www.broadwayworld.com/shows/backstage.php?showid=333897', 'https://www.broadwayworld.com/shows/backstage.php?showid=331062', 'https://www.broadwayworld.com/shows/backstage.php?showid=333641', 'https://www.broadwayworld.com/shows/backstage.php?showid=333896', 'https://www.broadwayworld.com/shows/backstage.php?showid=334644', 'https://www.broadwayworld.com/shows/backstage.php?showid=334247', 'https://www.broadwayworld.com/shows/backstage.php?showid=334144', 'https://www.broadwayworld.com/shows/backstage.php?showid=334403', 'https://www.broadwayworld.com/shows/backstage.php?showid=334537', 'https://www.broadwayworld.com/shows/backstage.php?showid=334503', 'https://www.broadwayworld.com/shows/backstage.php?showid=334343', 'https://www.broadwayworld.com/shows/backstage.php?showid=333989', 'https://www.broadwayworld.com/shows/backstage.php?showid=334638', 'https://www.broadwayworld.com/shows/backstage.php?showid=334460', 'https://www.broadwayworld.com/shows/backstage.php?showid=334147', 'https://www.broadwayworld.com/shows/backstage.php?showid=334173', 'https://www.broadwayworld.com/shows/backstage.php?showid=334559', 'https://www.broadwayworld.com/shows/backstage.php?showid=334294', 'https://www.broadwayworld.com/shows/backstage.php?showid=334180', 'https://www.broadwayworld.com/shows/backstage.php?showid=334246', 'https://www.broadwayworld.com/shows/backstage.php?showid=332493', 'https://www.broadwayworld.com/shows/backstage.php?showid=334334', 'https://www.broadwayworld.com/shows/backstage.php?showid=334329', 'https://www.broadwayworld.com/shows/backstage.php?showid=334175', 'https://www.broadwayworld.com/shows/backstage.php?showid=334146', 'https://www.broadwayworld.com/shows/backstage.php?showid=334374', 'https://www.broadwayworld.com/shows/backstage.php?showid=334363', 'https://www.broadwayworld.com/shows/backstage.php?showid=334213', 'https://www.broadwayworld.com/shows/backstage.php?showid=333521', 'https://www.broadwayworld.com/shows/backstage.php?showid=334653', 'https://www.broadwayworld.com/shows/backstage.php?showid=334128', 'https://www.broadwayworld.com/shows/backstage.php?showid=334066', 'https://www.broadwayworld.com/shows/backstage.php?showid=334399', 'https://www.broadwayworld.com/shows/backstage.php?showid=332140', 'https://www.broadwayworld.com/shows/backstage.php?showid=334504', 'https://www.broadwayworld.com/shows/backstage.php?showid=334470', 'https://www.broadwayworld.com/shows/backstage.php?showid=333988', 'https://www.broadwayworld.com/shows/backstage.php?showid=333923', 'https://www.broadwayworld.com/shows/backstage.php?showid=333104', 'https://www.broadwayworld.com/shows/backstage.php?showid=333542', 'https://www.broadwayworld.com/shows/backstage.php?showid=334067', 'https://www.broadwayworld.com/shows/backstage.php?showid=333721', 'https://www.broadwayworld.com/shows/backstage.php?showid=333986', 'https://www.broadwayworld.com/shows/backstage.php?showid=333895', 'https://www.broadwayworld.com/shows/backstage.php?showid=333388', 'https://www.broadwayworld.com/shows/backstage.php?showid=333688', 'https://www.broadwayworld.com/shows/backstage.php?showid=333622', 'https://www.broadwayworld.com/shows/backstage.php?showid=333148', 'https://www.broadwayworld.com/shows/backstage.php?showid=333898', 'https://www.broadwayworld.com/shows/backstage.php?showid=333899', 'https://www.broadwayworld.com/shows/backstage.php?showid=333674', 'https://www.broadwayworld.com/shows/backstage.php?showid=333689', 'https://www.broadwayworld.com/shows/backstage.php?showid=334118', 'https://www.broadwayworld.com/shows/backstage.php?showid=333145', 'https://www.broadwayworld.com/shows/backstage.php?showid=333480', 'https://www.broadwayworld.com/shows/backstage ...
# 1877

# %%
#testing functions from selenium package 
#will delete this chunk later
driver = webdriver.Chrome()
productions = ['The King and I', 'Dear Evan Hansen', 'Spring Awakening']
for prod in productions:
    driver.get('https://www.ibdb.com/shows/')     #website I am searching from (IBDB)
    e = driver.find_element('name','ShowProperName')    #locating the searchbar
    e.send_keys(prod)       #automating the searches (will store results in a list later)
    e.send_keys(Keys.ENTER)

# %%
#need to get "/broadway-production/<name-of-show-number>" for every production
#href is important
URL = "https://www.ibdb.com/shows/"
